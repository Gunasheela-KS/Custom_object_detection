# %% [markdown]
# <a href="https://colab.research.google.com/github/Gunasheela-KS/Custom_object_detection/blob/main/Copy_of_custom_object_detection_Image_Video_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.0/166.8 GB disk)

# %%
pwd
# Out:
# '/content/yolov5'

# %% [markdown]
# ### **Load the data**

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# # **Train YOLOv5s on custom data for 120 epochs with batch size as 2**

# %%
# Train YOLOv5s on custom data for 120 epochs with batch size as 2
# !python train.py --img 640 --batch 2 --epochs 120 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=120, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %% [markdown]
# ### **Results**

# %%
from utils.plots import plot_results 
plot_results('/content/yolov5/runs/train/exp/results.csv')  # plot 'results.csv' as 'results.png'

# %% [markdown]
# ### **Inference on images**

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.5 --source /content/train_data/inference/2.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/train_data/inference/2.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/train_data/inference/2.jpg: 256x640 1 barack, Done. (0.026s)
# Speed: 0.6ms pre-process, 26.2ms inference, 4.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
display.Image(filename='/content/yolov5/runs/detect/exp3/2.jpg', width=600)

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.5 --source /content/barack_mark.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/barack_mark.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/barack_mark.jpg: 352x640 1 barack, Done. (0.027s)
# Speed: 0.4ms pre-process, 26.6ms inference, 2.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %%
display.Image(filename='/content/yolov5/runs/detect/exp8/barack_mark.jpg', width=600)

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.5 --source /content/elon_mark.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/elon_mark.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/elon_mark.jpg: 448x640 Done. (0.028s)
# Speed: 0.5ms pre-process, 28.4ms inference, 5.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp9

# %%
display.Image(filename='/content/yolov5/runs/detect/exp9/elon_mark.jpg', width=600)

# %%
pwd
# Out:
# '/content/yolov5'

# %% [markdown]
# ### **Inference on videos**

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.5 --source /content/barack_video.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/barack_video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/916) /content/barack_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (2/916) /content/barack_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (3/916) /content/barack_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (4/916) /content/barack_video.mp4: 384x640 Done. (0.027s)
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.5 --source /content/mark_barack_video.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/mark_barack_video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2071) /content/mark_barack_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (2/2071) /content/mark_barack_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (3/2071) /content/mark_barack_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (4/2071) /content/mark_barack_video.mp4: 384x640 Done. (0.026s)
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.5 --source /content/bill_gates_video.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/bill_gates_video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2056) /content/bill_gates_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (2/2056) /content/bill_gates_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (3/2056) /content/bill_gates_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (4/2056) /content/bill_gates_video.mp4: 384x640 Done. (0.027s)
# ...

# %% [markdown]
# # **Train YOLOv5s on custom_data for 250 epochs with batch size 2**

# %%
# Train YOLOv5s on custom_data for 250 epochs with batch size 2
# !python train.py --img 640 --batch 2 --epochs 250 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 3
# wandb: You chose 'Don't visualize my results'
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=250, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %% [markdown]
# # **Inference on images**

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.35 --source /content/barack_mark.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/barack_mark.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/barack_mark.jpg: 352x640 2 baracks, 1 mark, Done. (0.027s)
# Speed: 0.5ms pre-process, 26.6ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp10

# %%
display.Image(filename='/content/yolov5/runs/detect/exp10/barack_mark.jpg', width=600)

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.5 --source /content/elon_mark.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/elon_mark.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/elon_mark.jpg: 448x640 1 elon, 1 mark, Done. (0.028s)
# Speed: 0.5ms pre-process, 28.3ms inference, 2.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp12

# %%
display.Image(filename='/content/yolov5/runs/detect/exp12/elon_mark.jpg', width=600)

# %% [markdown]
# # **Inference on videos**

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.35 --source /content/mark_barack_video.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/mark_barack_video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2071) /content/mark_barack_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (2/2071) /content/mark_barack_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (3/2071) /content/mark_barack_video.mp4: 384x640 Done. (0.027s)
# video 1/1 (4/2071) /content/mark_barack_video.mp4: 384x640 Done. (0.027s)
# ...

# %%
from utils.plots import plot_results 
plot_results('/content/yolov5/runs/train/exp2/results.csv')  # plot 'results.csv' as 'results.png'

# %% [markdown]
# #**Train the model for 250 epochs at batch size:16**

# %%
# Train YOLOv5s on custom_data for 250 epochs with batch size 2
# !python train.py --img 640 --batch 16 --epochs 250 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=250, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %% [markdown]
# ### **TensorRT**

# %%
# !git clone https://github.com/BlueMirrors/Yolov5-TensorRT.git
# Out:
# Cloning into 'Yolov5-TensorRT'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 56 (delta 26), reused 33 (delta 13), pack-reused 0
# Unpacking objects: 100% (56/56), done.

# %%
# %cd Yolov5-TensorRT
# Out:
# /content/yolov5/Yolov5-TensorRT

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/BlueMirrors/cvu to /tmp/pip-req-build-t36l9m_u
#   Running command git clone -q https://github.com/BlueMirrors/cvu /tmp/pip-req-build-t36l9m_u
# ...
#   Created wheel for cvu-python: filename=cvu_python-0.0.1a1-py3-none-any.whl size=60193 sha256=1bfd8169efbb21d4273ce898ed8c6191cec558e0d2f648d8c4e80e59aa1727da
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cm7nyv5s/wheels/44/ae/52/012448aa22be20ca8fe1f0fbc2dd4182ecde9ee2754c7ec03b
# Successfully built cvu-python
# ...

# %%
# !pip install pycuda==2021.1
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 9.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 68 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 78 kB 7.0 MB/s
# ...
#   Created wheel for pycuda: filename=pycuda-2021.1-cp37-cp37m-linux_x86_64.whl size=626634 sha256=b0d234e99a5bff717bb0ac35c87fc20da8a7c82386eb970c24071e93f43ec264
#   Stored in directory: /root/.cache/pip/wheels/c4/ef/49/dc6a5feb8d980b37c83d465ecab24949a6aa19458522a9e001
# ...
#   Created wheel for pytools: filename=pytools-2022.1.4-py2.py3-none-any.whl size=64565 sha256=f2033b32d81abaee82d6e051f0c10c33088ddf859b98b6da875612025dba3b8f
#   Stored in directory: /root/.cache/pip/wheels/3d/fa/11/780768f5d348db6336b7237aa800c324685d6fc792a7bfde55
# Successfully built pycuda pytools
# ...

# %%
# !pip install nvidia-tensorrt==8.0.1.6 --index-url https://pypi.ngc.nvidia.com
# Out:
# Looking in indexes: https://pypi.ngc.nvidia.com
# ...
#      |████████████████████████████████| 264.9 MB 27 kB/s
# ...
#      |████████████████████████████████| 801 kB 35.2 MB/s
# ...
#      |████████████████████████████████| 20.4 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 778.5 MB 11 kB/s
# ...
#      |████████████████████████████████| 250.3 MB 8.9 kB/s
# ...

# %% [markdown]
# # **TensorRT inference**

# %%
pwd
# Out:
# '/content/yolov5/Yolov5-TensorRT'

# %% [markdown]
# # **Export trained model weights to TensorRT**

# %%
# !python /content/yolov5/export.py --data /content/yolov5/data/custom_data.yaml --weights /content/yolov5/runs/train/exp/weights/best.pt --include engine --imgsz 640 640 --device 0
# Out:
# export: data=/content/yolov5/data/custom_data.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=0, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['engine']
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/yolov5/runs/train/exp/weights/best.pt with output shape (1, 25200, 8) (13.7 MB)
#
# ONNX: starting export with onnx 1.11.0...
# WARNING: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function.
# ...

# %% [markdown]
# #Tensor RT Inference

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.engine --source /content/elon_mark.jpg --data /content/yolov5/data/custom_data.yaml
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.engine'], source=/content/elon_mark.jpg, data=/content/yolov5/data/custom_data.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Loading /content/yolov5/runs/train/exp/weights/best.engine for TensorRT inference...
# [TensorRT] INFO: [MemUsageChange] Init CUDA: CPU +0, GPU +0, now: CPU 0, GPU 355 (MiB)
# [TensorRT] INFO: Loaded engine size: 28 MB
# [TensorRT] INFO: [MemUsageSnapshot] deserializeCudaEngine begin: CPU 0 MiB, GPU 355 MiB
# ...

# %%
display.Image(filename='/content/yolov5/runs/detect/exp11/elon_mark.jpg',width=600)

# %% [markdown]
# # **Tensor RT video inference**

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.engine --source /content/mark_barack_video.mp4 --data /content/yolov5/data/custom_data.yaml
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.engine'], source=/content/mark_barack_video.mp4, data=/content/yolov5/data/custom_data.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Loading /content/yolov5/runs/train/exp/weights/best.engine for TensorRT inference...
# [TensorRT] INFO: [MemUsageChange] Init CUDA: CPU +0, GPU +0, now: CPU 0, GPU 355 (MiB)
# [TensorRT] INFO: Loaded engine size: 28 MB
# [TensorRT] INFO: [MemUsageSnapshot] deserializeCudaEngine begin: CPU 0 MiB, GPU 355 MiB
# ...

# %% [markdown]
# # **Export Trained weights to ONNX**

# %%
# !python /content/yolov5/export.py --weights /content/yolov5/runs/train/exp/weights/best.pt --dynamic --include torchscript onnx
# Out:
# export: data=../data/coco128.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=True, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/yolov5/runs/train/exp/weights/best.pt with output shape (1, 25200, 8) (13.7 MB)
#
# TorchScript: starting export with torch 1.10.0+cu111...
# TorchScript: export success, saved as /content/yolov5/runs/train/exp/weights/best.torchscript (27.0 MB)
#
# ONNX: starting export with onnx 1.11.0...
# ONNX: export success, saved as /content/yolov5/runs/train/exp/weights/best.onnx (26.8 MB)
#
# ...

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.onnx --img 640 --conf 0.35 --source /content/elon_mark.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.onnx'], source=/content/elon_mark.jpg, data=../data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Loading /content/yolov5/runs/train/exp/weights/best.onnx for ONNX Runtime inference...
# image 1/1 /content/elon_mark.jpg: 640x640 1 elon, 1 mark, Done. (0.010s)
# Speed: 5.3ms pre-process, 10.5ms inference, 2.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to ../runs/detect/exp2

# %%
display.Image(filename='/content/yolov5/runs/detect/exp2/elon_mark.jpg',width=600)
